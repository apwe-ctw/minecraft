# %% [markdown]
# ### Programming using Python - Financial Calculator and Minecraft
#
# - Lesson plan is based on a 9:15AM - 3:30M day (including snack breaks!)
#
# ### Volunteer Briefing (45 mins: 9:15am -10:00am)
#
# - Run through of day
# - Setup and test Raspberry Pi
# - Try out Minecraft and RasPi
#
# ### Participants Arrive + Settle (15 mins: 10am - 10:15am)
#
# ### Welcome (15 mins: 10:15am - 10:30am)
#
# - Run through of the day
# - TWF intro
#
#
#
# ### Setup Raspberry Pi (15 mins: 10:30am - 10:45am)
# - What is a Raspberry?
# - Pi board
# - SD Card (pre-setup)
# - HDMI (display) cable
# - Keyboard
# - Mouse
# - Power
#
# ### Game to introduce programming (15 mins: 10:45am - 11:00am)
# - http://compute-it.toxicode.fr/?hour-of-code
#
# ### Introduction to Python (30 mins: 11:00am - 11:30am)
# - [Python RefCard](https://dzone.com/refcardz/core-python)
# - [Jupyter Notebook](notebook/)
# - Start with the 'Introduction' notebook
#
# ### A Standalone Python Application - Financial Calculator (30 mins: 11:30am - 12:00pm)
# - [Jupyter Notebook](notebook/)
# - Start the 'Financial Calculator' notebook
#
# ### Electronics Introduction + Setup (30 mins 12:00pm - 12:30pm)
# - [Jupyter Notebook](notebook/)
# - 'Minecraft Electronics' notebook
# - Complete the introduction, simple circuit and programmable circuit
#
# - [Jupyter Notebook](notebook/)
# - Start the 'Financial Calculator' notebook
# - Once done, remember to make the LED blinks in the financial calculator
# - Check out the last section of the 'Financial Calculator' notebook
#
#
# ### Lunch Break (45 mins: 12:30pm - 1:15pm)
# - Now watch some minecraft python videos
#
#
# ### Introduction to Minecraft (15 mins: 1:15pm - 1:30pm)
#   - Play the game!
#     - Menu -> Games -> Minecraft
#     - Start Game -> Create New (you can create new worlds till you get one you like)
#   - Keys:
#
#     Key | Action
#     --- | ------
#     W	| Forward
#     A	| Left
#     S	| Backward
#     D	|	Right
#     Left-click | Hit
#     Right-click | Place block
#     Mouse-scroll | Hotbar select
#     E	|	Inventory
#     Space	|	Jump / Fly up
#     Left Shift | Crouch / Fly down
#     Double Space	|	Fly / Fall
#     Esc	| Pause / Game menu
#     Tab	| Release mouse cursor
#
# - Minecraft coordinate system:
#   - x-axis: East (positive), West (negative)
#   - z-axis: South (positive), North (negative)
#   - y-axis: High (positive), Low (negative)
#   - Right-handed coordinates: thumb = x, index = y, middle = z
#
# ![Coordinate Systems](notebook/images/left_right_hand.gif)
#
# ## Try these out!
#     - Move to position 0,0,0
#     - Move to position 3,8,7
#
#
#
# ### Minecraft Programming (45 mins: 1:30pm - 2:15pm)
# - [Jupyter Notebook](notebook/)
# - 'Minecraft Programming' notebook
#
# ![hello](screenshots/hello_world.png)
#
# - Build your house!
#
# ![House](screenshots/house.png)
#
# ### Electronics + MineCraft (60 mins 2:15pm - 3:15pm)
# - SmartHome and Bulldozer Exercise
# - [Jupyter Notebook](notebook/)
# - 'Minecraft Electronics' notebook
#
#
# ### It's a Wrap! (15 mins 3:15pm - 3:30pm)
